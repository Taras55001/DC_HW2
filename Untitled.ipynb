# %%
import pandas as pd
#Вивести перші рядки таблиці за допомогою методу head
url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
list_of_df = pd.read_html(url)
numbers = list_of_df[5]
df = list_of_df[10]
df.head()
# Out:
#     Рік Чисельність населення (тис. осіб) Живих народжень  Смертей  \
#     Рік Чисельність населення (тис. осіб) Живих народжень  Смертей
# 0  1950                            36 905         844 585  315 300
# 1  1951                            37 569         858 052  327 500
# 2  1952                            38 141         846 434  325 700
# 3  1953                            38 678         795 652  326 800
# 4  1954                            39 131         845 128  318 500
#
#   Природний приріст Природний приріст (‰)                     \
#   Природний приріст        Народжуваність Смертність Приріст
# 0           529 300                   229         85     143
# 1           530 600                   228         87     141
# 2           520 700                   222         85     137
# 3           468 900                   206         84     121
# 4           526 600                   216         81     135
#
#   Фертильність (СКН) #                 Офіційних абортів
# ...

# %%
#Визначте кількість рядків та стовпців у датафреймі (атрибут shape)
for df in list_of_df:
    print(f"кількість рядків та стовпців:{df.shape}")
#print(df["Чисельність населення (тис. осіб)"])
# Out:
# кількість рядків та стовпців:(29, 2)
# кількість рядків та стовпців:(1, 2)
# кількість рядків та стовпців:(1, 2)
# кількість рядків та стовпців:(1, 2)
# кількість рядків та стовпців:(1, 1)
# кількість рядків та стовпців:(30, 3)
# кількість рядків та стовпців:(16, 3)
# кількість рядків та стовпців:(4, 4)
# кількість рядків та стовпців:(1, 2)
# кількість рядків та стовпців:(32, 4)
# кількість рядків та стовпців:(75, 12)
# кількість рядків та стовпців:(7, 18)
# кількість рядків та стовпців:(28, 9)
# кількість рядків та стовпців:(17, 17)
# кількість рядків та стовпців:(1, 15)
# кількість рядків та стовпців:(21, 4)
# кількість рядків та стовпців:(32, 5)
# кількість рядків та стовпців:(7, 18)
# кількість рядків та стовпців:(8, 3)
# кількість рядків та стовпців:(1, 2)
# кількість рядків та стовпців:(1, 16)
# кількість рядків та стовпців:(3, 16)
# кількість рядків та стовпців:(21, 10)
# кількість рядків та стовпців:(2, 15)
# кількість рядків та стовпців:(1, 2)
# ...

# %%
#Замініть у таблиці значення "—" на значення NaN
df.fillna("—", pd.NA, inplace=True)

#missing_percentage = df.isnull().mean() * 100
#print("Частка пропусків у кожній колонці:")
#print(missing_percentage)
#df = df.iloc[:-1]
#df.fillna(df.mean(), inplace=True)
#regions_higher_than_average = df[df['2019'] > df['2019'].mean()]['Region']
#print("Регіони з вищим рівнем народжуваності у 2019 році:")
#print(regions_higher_than_average)
#region_with_highest_birthrate_2014 = df[df['2014'] == df['2014'].max()]['Region'].values[0]
#print("Регіон з найвищою народжуваністю у 2014 році:", region_with_highest_birthrate_2014)

# %%
#Визначте типи всіх стовпців за допомогою dataframe.dtypes
for df in list_of_df:
    print("Типи стовпців:")
    print(df.dtypes)
# Out:
# Типи стовпців:
# Населення України      object
# Населення України.1    object
# dtype: object
# Типи стовпців:
# 0    float64
# 1     object
# dtype: object
# Типи стовпців:
# 0    float64
# 1     object
# dtype: object
# Типи стовпців:
# 0    float64
# 1     object
# dtype: object
# Типи стовпців:
# 0    object
# dtype: object
# Типи стовпців:
# Рік             int64
# Чисельність    object
# Примітка       object
# dtype: object
# Типи стовпців:
# Рік          int64
# Позиція     object
# Примітка    object
# dtype: object
# Типи стовпців:
# Unnamed: 0        object
# січень 2021[i]    object
# Unnamed: 2        object
# січень 2022[i]    object
# dtype: object
# Типи стовпців:
# 0    float64
# 1     object
# dtype: object
# Типи стовпців:
# Рік            object
# Природний       int64
# Міграційний     int64
# Загальний       int64
# dtype: object
# Типи стовпців:
# Рік                                Рік                                  object
# ...

# %%
#Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"
for df in pd.read_html(url):
    df.replace(pd.NA, 0, inplace=True)

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
for df in pd.read_html(url):
    missing_percentage = df.isnull().mean() * 100
    print(f"Частка пропусків у:{', '.join([(str(i))[:10] for i in df.columns])}")
    print(missing_percentage)
# Out:
# Частка пропусків у:Населення , Населення
# Населення України      0.0
# Населення України.1    0.0
# dtype: float64
# Частка пропусків у:0, 1
# 0    100.0
# 1      0.0
# dtype: float64
# Частка пропусків у:0, 1
# 0    100.0
# 1      0.0
# dtype: float64
# Частка пропусків у:0, 1
# 0    100.0
# 1      0.0
# dtype: float64
# Частка пропусків у:0
# 0    0.0
# dtype: float64
# Частка пропусків у:Рік, Чисельніст, Примітка
# Рік            0.000000
# Чисельність    0.000000
# Примітка       3.333333
# dtype: float64
# Частка пропусків у:Рік, Позиція, Примітка
# Рік          0.00
# Позиція      0.00
# Примітка    18.75
# dtype: float64
# Частка пропусків у:Unnamed: 0, січень 202, Unnamed: 2, січень 202
# Unnamed: 0        0.0
# січень 2021[i]    0.0
# Unnamed: 2        0.0
# січень 2022[i]    0.0
# dtype: float64
# Частка пропусків у:0, 1
# 0    100.0
# 1      0.0
# dtype: float64
# Частка пропусків у:Рік, Природний, Міграційни, Загальний
# Рік            0.0
# Природний      0.0
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(df['Region'], df['2019'])
plt.xlabel('Регіони')
plt.ylabel('Народжуваність у 2019 році')
plt.xticks(rotation=90)
plt.title('Народжуваність по регіонах у 2019 році')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 4
#       1 import matplotlib.pyplot as plt
# ...
